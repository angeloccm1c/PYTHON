# %% [markdown]
# <a href="https://colab.research.google.com/github/angeloccm1c/PYTHON/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AULA 1   ⚓   ♈   ⏰

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de Ana são {pontos_ana}")
print(f"Os pontos totais de Ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de Ana são 46
# Os pontos totais de Ana e Rodrigo são 70

# %% [markdown]
# #AULA 3   ✈   ⚛   ▶

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigos = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigos

print("João recebeu", figurinhas_joao, "figurinhas")

# %% [markdown]
# #AULA 4   🧑   🏝   🚣

# %%
def tabuada(numero):
    for contador in range(1, 11): # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 9
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# #AULA 5

# %%
def tabuada(numero):
    for contador in range(1, 11): # Gera números de 1 a 10
        print(f"{numero} / {contador} = {numero // contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 9
# 9 / 1 = 9
# 9 / 2 = 4
# 9 / 3 = 3
# 9 / 4 = 2
# 9 / 5 = 1
# 9 / 6 = 1
# 9 / 7 = 1
# 9 / 8 = 1
# 9 / 9 = 1
# 9 / 10 = 0

# %% [markdown]
# #AULA 7 LISTAS   🦘   ⚾   ⚫

# %%
import random
dica = [
Acredite em si mesmo e você será imparável! 💪,
Cada dia é uma nova oportunidade para brilhar. ✨,
Quando a vida te der limões, faça uma limonada. 🍋➡️🥤,
Não seja empurrado pelos seus problemas, seja guiado pelos seus sonhos. 🌧️➡️🌈,
O melhor de mim ainda está para chegar. 🚀,
A jornada mais longa começa com um único passo. 🚶‍♀️➡️🏆,
Não confunda as pessoas que estão à sua volta com as pessoas que estão com você. ❤️‍🔥,
]
while True:
  pedido = input("digite 'dica' para receber uma dica `ou 'sair' para encerrar \n ")

  if pedido == "dica":
    dica = random.choice(dicas) # escolhe uma dica aleatória sair
